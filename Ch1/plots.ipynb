# %%
# Plotting
# To show the plot in the interactive session or the notebook, use plt.ion() and then plt.plot(), finally plt.show()
# We can use arguments such as '-bo' for plt.show() indicating "-" (a line), "b" (blue color) 
# & "o" (circle marker)
import matplotlib.pyplot as plt
# I don't want to import specific methods. I want all for now.
plt.ion()
temps = [71, 71, 68, 69, 68, 69, 68, 74, 77, 82, 85, 86, 88, 86, 85, 86, 84, 79, 77, 75, 73, 71, 70, 70, 69, 69, 69, 69, 67,
68, 68, 73, 76, 77, 82, 84, 84, 81, 80, 78, 79, 78, 73, 72,
70, 70, 68, 67]
plt.plot(temps, '-bo')
# Saving the plot as PDF
plt.savefig('temperature.pdf', format='pdf')
plt.show()

# %%
# Maybe now try to save plot as PNG
plt.plot(temps, "-gx")
plt.savefig("temp.png", format="png")
plt.show()
# It seems double quotes or single quotes doesn't matter!

# %%
# Try JPEG now?
plt.plot(temps, "--r+")
plt.savefig("temps.jpg", format="jpg")
plt.show()

# %%
# This looks cool. Will get back!
